# %%
# !pip install etna[all]

# %%
# !pip install etna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting etna
#   Downloading etna-2.0.0-py3-none-any.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.3/304.3 kB 7.5 MB/s eta 0:00:00
# Collecting Bottleneck<2.0.0,>=1.3.4 (from etna)
#   Downloading Bottleneck-1.3.7-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (354 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.0/354.0 kB 27.6 MB/s eta 0:00:00
# Collecting Deprecated==1.2.13 (from etna)
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting boto3<2.0,>=1.5 (from etna)
#   Downloading boto3-1.26.151-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 13.9 MB/s eta 0:00:00
# Collecting botocore (from etna)
#   Downloading botocore-1.29.151-py3-none-any.whl (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 59.0 MB/s eta 0:00:00
# Collecting catboost>=0.21 (from etna)
#   Downloading catboost-1.2-cp310-cp310-manylinux2014_x86_64.whl (98.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 MB 7.3 MB/s eta 0:00:00
# Collecting dill<0.4.0,>=0.3.4 (from etna)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 11.6 MB/s eta 0:00:00
# Collecting holidays<0.14,>=0.13 (from etna)
#   Downloading holidays-0.13-py3-none-any.whl (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.1/172.1 kB 17.0 MB/s eta 0:00:00
# Collecting hydra-slayer<0.3.0,>=0.2.0 (from etna)
#   Downloading hydra_slayer-0.2.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: ipywidgets<8.0.0,>=7.6.5 in /usr/local/lib/python3.10/dist-packages (from etna) (7.7.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from etna) (1.2.0)
# Collecting loguru<0.6.0,>=0.5.3 (from etna)
#   Downloading loguru-0.5.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from etna) (3.7.1)
# Collecting numba<0.56.0,>=0.53.1 (from etna)
#   Downloading numba-0.55.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 64.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from etna) (1.22.4)
# Collecting omegaconf<3.0.0,>=2.1.1 (from etna)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas<2.0,>=1.1 in /usr/local/lib/python3.10/dist-packages (from etna) (1.5.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from etna) (5.13.1)
# Collecting pmdarima>=1.8.0 (from etna)
#   Downloading pmdarima-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 14.4 MB/s eta 0:00:00
# Collecting ruptures==1.1.5 (from etna)
#   Downloading ruptures-1.1.5.tar.gz (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.7/236.7 kB 21.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scikit-learn<2,>=0.24 in /usr/local/lib/python3.10/dist-packages (from etna) (1.2.2)
# Collecting scipy<1.8.0 (from etna)
#   Downloading scipy-1.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 16.9 MB/s eta 0:00:00
# Collecting seaborn<0.12.0,>=0.11.1 (from etna)
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 25.3 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels<0.14,>=0.12 in /usr/local/lib/python3.10/dist-packages (from etna) (0.13.5)
# Collecting tbats<2.0.0,>=1.1.0 (from etna)
#   Downloading tbats-1.1.3-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: toml<0.11.0,>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from etna) (0.10.2)
# Collecting typer<0.5.0,>=0.4.0 (from etna)
#   Downloading typer-0.4.2-py3-none-any.whl (27 kB)
# Collecting types-Deprecated==1.2.9 (from etna)
#   Downloading types_Deprecated-1.2.9-py3-none-any.whl (3.2 kB)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from etna) (4.5.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from Deprecated==1.2.13->etna) (1.14.1)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0,>=1.5->etna)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0 (from boto3<2.0,>=1.5->etna)
#   Downloading s3transfer-0.6.1-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore->etna) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore->etna) (1.26.15)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost>=0.21->etna) (0.20.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost>=0.21->etna) (1.16.0)
# Requirement already satisfied: convertdate>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from holidays<0.14,>=0.13->etna) (2.4.0)
# Collecting hijri-converter (from holidays<0.14,>=0.13->etna)
#   Downloading hijri_converter-2.3.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: korean-lunar-calendar in /usr/local/lib/python3.10/dist-packages (from holidays<0.14,>=0.13->etna) (0.3.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8.0.0,>=7.6.5->etna) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8.0.0,>=7.6.5->etna) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8.0.0,>=7.6.5->etna) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8.0.0,>=7.6.5->etna) (3.6.4)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8.0.0,>=7.6.5->etna) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8.0.0,>=7.6.5->etna) (3.0.7)
# Collecting llvmlite<0.39,>=0.38.0rc1 (from numba<0.56.0,>=0.53.1->etna)
#   Downloading llvmlite-0.38.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba<0.56.0,>=0.53.1->etna) (67.7.2)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf<3.0.0,>=2.1.1->etna)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 11.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from omegaconf<3.0.0,>=2.1.1->etna) (6.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0,>=1.1->etna) (2022.7.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima>=1.8.0->etna) (0.29.34)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=0.24->etna) (3.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->etna) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->etna) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->etna) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->etna) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->etna) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->etna) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->etna) (3.0.9)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels<0.14,>=0.12->etna) (0.5.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.5.0,>=0.4.0->etna) (8.1.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->etna) (8.2.2)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /usr/local/lib/python3.10/dist-packages (from convertdate>=2.3.0->holidays<0.14,>=0.13->etna) (0.5.12)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.6.5->etna) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.6.5->etna) (6.3.1)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna)
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 72.9 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (4.8.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (6.4.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.8.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (3.1.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (5.3.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (5.8.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.2.6)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (3.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (2.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.7.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (4.3.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.6.5->etna) (2.21)
# Building wheels for collected packages: ruptures, antlr4-python3-runtime
#   Building wheel for ruptures (pyproject.toml) ... done
#   Created wheel for ruptures: filename=ruptures-1.1.5-cp310-cp310-linux_x86_64.whl size=1002359 sha256=7417ab460e6b77a0d711177d5474344d6c63b304ef9148eb190c0b2f2e954541
#   Stored in directory: /root/.cache/pip/wheels/a7/67/53/cb08e28090f1f2df27a417e1f72654a7d114cca2daf7788250
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=3b8a855a2c84b1709dbaaf86321a06a8247af06df6e3a6f1e2fb7e4f876867e9
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built ruptures antlr4-python3-runtime
# Installing collected packages: types-Deprecated, antlr4-python3-runtime, typer, scipy, omegaconf, loguru, llvmlite, jmespath, jedi, hydra-slayer, hijri-converter, dill, Deprecated, Bottleneck, ruptures, numba, holidays, botocore, seaborn, s3transfer, catboost, pmdarima, boto3, tbats, etna
#   Attempting uninstall: typer
#     Found existing installation: typer 0.7.0
#     Uninstalling typer-0.7.0:
#       Successfully uninstalled typer-0.7.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.39.1
#     Uninstalling llvmlite-0.39.1:
#       Successfully uninstalled llvmlite-0.39.1
#   Attempting uninstall: numba
#     Found existing installation: numba 0.56.4
#     Uninstalling numba-0.56.4:
#       Successfully uninstalled numba-0.56.4
#   Attempting uninstall: holidays
#     Found existing installation: holidays 0.25
#     Uninstalling holidays-0.25:
#       Successfully uninstalled holidays-0.25
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# arviz 0.15.1 requires scipy>=1.8.0, but you have scipy 1.7.3 which is incompatible.
# prophet 1.1.3 requires holidays>=0.14.2, but you have holidays 0.13 which is incompatible.
# Successfully installed Bottleneck-1.3.7 Deprecated-1.2.13 antlr4-python3-runtime-4.9.3 boto3-1.26.151 botocore-1.29.151 catboost-1.2 dill-0.3.6 etna-2.0.0 hijri-converter-2.3.1 holidays-0.13 hydra-slayer-0.2.0 jedi-0.18.2 jmespath-1.0.1 llvmlite-0.38.1 loguru-0.5.3 numba-0.55.2 omegaconf-2.3.0 pmdarima-2.0.3 ruptures-1.1.5 s3transfer-0.6.1 scipy-1.7.3 seaborn-0.11.2 tbats-1.1.3 typer-0.4.2 types-Deprecated-1.2.9

# %%
import numpy as np
import pandas as pd
from etna.datasets import TSDataset
# Out:
# /usr/local/lib/python3.10/dist-packages/etna/settings.py:37: UserWarning: etna[torch] is not available, to install it, run `pip install etna[torch]`
#   warnings.warn("etna[torch] is not available, to install it, run `pip install etna[torch]`")
# /usr/local/lib/python3.10/dist-packages/etna/settings.py:45: UserWarning: wandb is not available, to install it, run `pip install etna[wandb]`
#   warnings.warn("wandb is not available, to install it, run `pip install etna[wandb]`")
# /usr/local/lib/python3.10/dist-packages/etna/settings.py:61: UserWarning: `tsfresh` is not available, to install it, run `pip install tsfresh==0.19.0 && pip install protobuf==3.20.1`
#   warnings.warn(

# %%
df_flat = pd.read_csv("personal_transactions.csv")
filtered_data = df_flat[df_flat.iloc[:, 3] == "debit"]

# Удаление столбцов
columns_to_drop = [1, 3, 4, 5]
filtered_data = filtered_data.drop(filtered_data.columns[columns_to_drop], axis=1)

# Назначение имен столбцам
filtered_data.columns = ['timestamp', 'target']
filtered_data['timestamp'] = pd.to_datetime(filtered_data['timestamp'])

# Группировка данных по уникальным датам и суммирование чисел
grouped_data = filtered_data.groupby('timestamp')['target'].sum().reset_index()

# Результат
print(grouped_data)
# Out:
#      timestamp   target
# 0   2018-01-01    11.11
# 1   2018-01-02  1271.66
# 2   2018-01-04    11.76
# 3   2018-01-05    25.85
# 4   2018-01-06    18.45
# ..         ...      ...
# 404 2019-09-19    43.56
# 405 2019-09-22   131.10
# 406 2019-09-23    61.77
# 407 2019-09-28    37.73
# 408 2019-09-30    76.75
#
# [409 rows x 2 columns]

# %%
# filtered_data['timestamp'] = pd.to_datetime(filtered_data['target'])

# %%
type(filtered_data[filtered_data.columns[0]].values[0])
# Out:
# numpy.datetime64

# %%
print(grouped_data)
grouped_data = grouped_data.set_index('timestamp')
df_resampled = grouped_data.resample('D').fillna(method='ffill')
df_resampled = df_resampled.reset_index()
# Out:
#      timestamp   target
# 0   2018-01-01    11.11
# 1   2018-01-02  1271.66
# 2   2018-01-04    11.76
# 3   2018-01-05    25.85
# 4   2018-01-06    18.45
# ..         ...      ...
# 404 2019-09-19    43.56
# 405 2019-09-22   131.10
# 406 2019-09-23    61.77
# 407 2019-09-28    37.73
# 408 2019-09-30    76.75
#
# [409 rows x 2 columns]

# %%
df_resampled["segment"] = "main"
# df_resampled["cap"] = 8.5

# df_resampled['target'] = np.log(df_resampled['target'])
print(df_resampled)
# Out:
#      timestamp   target segment
# 0   2018-01-01    11.11    main
# 1   2018-01-02  1271.66    main
# 2   2018-01-03  1271.66    main
# 3   2018-01-04    11.76    main
# 4   2018-01-05    25.85    main
# ..         ...      ...     ...
# 633 2019-09-26    61.77    main
# 634 2019-09-27    61.77    main
# 635 2019-09-28    37.73    main
# 636 2019-09-29    37.73    main
# 637 2019-09-30    76.75    main
#
# [638 rows x 3 columns]

# %%
# приводим данные к ETNA-формату
df = TSDataset.to_dataset(df_resampled)
ts = TSDataset(df=df, freq = 'D')
print(ts)
# Out:
# segment        main
# feature      target
# timestamp
# 2018-01-01    11.11
# 2018-01-02  1271.66
# 2018-01-03  1271.66
# 2018-01-04    11.76
# 2018-01-05    25.85
# ...             ...
# 2019-09-26    61.77
# 2019-09-27    61.77
# 2019-09-28    37.73
# 2019-09-29    37.73
# 2019-09-30    76.75
#
# [638 rows x 1 columns]

# %%
# from etna import analysis
# from etna.analysis import sample_acf_plot

# analysis.sample_acf_plot(ts=ts)

# %%
ts.plot()

# %%
# train_ts, test_ts = ts.train_test_split(
#     train_start="2018-01-01",
#     train_end="2019-01-01",
#     test_start="2019-01-02",
#     test_end="2019-09-30",
# )

# %%
df = ts.to_pandas()
df = df.reset_index()
df.columns = ['timestamp', 'target']

dates = df['timestamp']



wnd_size = 5
df['target'] = df['target'].rolling(window=wnd_size).mean()
df = df[~np.isnan(df).any(axis=1)]
# df['target'] = np.log(df['target'])

# n_magnitude = 500
# df['target'] += np.sin(df.index / 10) * n_magnitude + n_magnitude

# Срез
n_each = 4
df = df.iloc[::n_each]
print(df.shape)



# df_tmp = df.set_index('timestamp')
# df_resampled = df_tmp.resample('D').fillna(method='ffill')
# df_resampled = df_resampled.reset_index()
# df = df_resampled

# Возвращение адекватных дат
date_true=df['timestamp']
df.index = range(df.shape[0])
df['timestamp'] = dates[:df.shape[0]]
df_tmp = df.copy()

print(df)


# приводим данные к ETNA-формату
df["segment"] = "main"
df = TSDataset.to_dataset(df)
ts2 = TSDataset(df=df, freq = 'D')
ts2.plot()

# df_tmp = df


tmp = int(df_tmp.shape[0]/2)
train_ts, test_ts = ts2.train_test_split(
    train_start=df_tmp['timestamp'][0],
    train_end=df_tmp['timestamp'][tmp],
    test_start=df_tmp['timestamp'][tmp+1],
    test_end=df_tmp['timestamp'][df_tmp.shape[0]-1],
)

# train_ts, test_ts = ts2.train_test_split(
#     train_start="2018-01-01",
#     train_end="2019-01-01",
#     test_start="2019-01-02",
#     test_end="2019-09-30",
# )
# Out:
# (159, 2)
#      timestamp   target
# 0   2018-01-01  518.408
# 1   2018-01-02   26.764
# 2   2018-01-03   65.786
# 3   2018-01-04   88.444
# 4   2018-01-05   77.084
# ..         ...      ...
# 154 2018-06-04  149.982
# 155 2018-06-05   56.484
# 156 2018-06-06  374.428
# 157 2018-06-07   71.994
# 158 2018-06-08   52.154
#
# [159 rows x 2 columns]

# %%
from etna.models import SARIMAXModel
from etna.analysis import plot_forecast
# Choose a horizon
HORIZON = 79

# Fit the model
model = SARIMAXModel(order = (10,0,0))
# model = ProphetModel()

model.fit(train_ts)

# Make the forecast
future_ts = train_ts.make_future(HORIZON)
forecast_ts = model.forecast(future_ts)

print(test_ts)
print(forecast_ts)

plot_forecast(forecast_ts, test_ts, train_ts,  n_train_samples=200)

plot_forecast(forecast_ts, train_ts,  n_train_samples=200)
# Out:
# /usr/local/lib/python3.10/dist-packages/etna/models/utils.py:118: FutureWarning: warn is deprecated (and never implemented) and will be removed in a future version.
#   freq = pd.infer_freq(timestamps, warn=False)
# /usr/local/lib/python3.10/dist-packages/etna/datasets/tsdataset.py:277: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   future_dates = pd.date_range(
# segment        main
# feature      target
# timestamp
# 2018-03-22   62.616
# 2018-03-23   43.050
# 2018-03-24   54.208
# 2018-03-25  415.112
# 2018-03-26  312.608
# ...             ...
# 2018-06-04  149.982
# 2018-06-05   56.484
# 2018-06-06  374.428
# 2018-06-07   71.994
# 2018-06-08   52.154
#
# [79 rows x 1 columns]
# segment           main
# feature         target
# timestamp
# 2018-03-22  284.756336
# 2018-03-23  -36.412184
# 2018-03-24  109.434145
# 2018-03-25   60.115215
# 2018-03-26   59.103721
# ...                ...
# 2018-06-04   62.858050
# 2018-06-05   26.196319
# 2018-06-06   43.656012
# 2018-06-07  471.192156
# 2018-06-08  180.995852
#
# [79 rows x 1 columns]

# %%
from etna.metrics import RMSE

# %%
rmse = RMSE()
# test_ts2 = test_ts
# forecast_ts2 = forecast_ts[:20]
rmse(y_true=test_ts, y_pred=forecast_ts)
# Out:
# {'main': 271.1753870709024}

# %%
from etna.models import AutoARIMAModel

# %%
model = AutoARIMAModel()
model.fit(train_ts)
# Out:
# /usr/local/lib/python3.10/dist-packages/etna/models/utils.py:118: FutureWarning: warn is deprecated (and never implemented) and will be removed in a future version.
#   freq = pd.infer_freq(timestamps, warn=False)
# AutoARIMAModel()

# %%
HORIZON = 100
future_ts = train_ts.make_future(HORIZON)
forecast_ts = model.forecast(future_ts)
print(future_ts == forecast_ts)
# print(forecast_ts.to_pandas()[0])



from etna.analysis import plot_forecast

plot_forecast(forecast_ts, test_ts, train_ts, n_train_samples=300)
# print(type(plot_forecast(forecast_ts, test_ts, train_ts, n_train_samples=30)))
# Out:
# /usr/local/lib/python3.10/dist-packages/etna/datasets/tsdataset.py:277: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   future_dates = pd.date_range(
# True

# %%
from etna.models import ProphetModel

# %%
print(train_ts)
model = ProphetModel(growth = 'linear', changepoints = None, n_changepoints = 100, changepoint_range = 1, yearly_seasonality = 'auto', weekly_seasonality = True, daily_seasonality = 'auto', holidays = None, seasonality_mode = 'additive', seasonality_prior_scale = 10.0, holidays_prior_scale = 10.0, changepoint_prior_scale = 0.05, mcmc_samples = 0, interval_width = 0.8, uncertainty_samples = 1000, stan_backend = None)
model.fit(train_ts)
# Out:
# segment        main
# feature      target
# timestamp
# 2018-01-01  518.408
# 2018-01-02   26.764
# 2018-01-03   65.786
# 2018-01-04   88.444
# 2018-01-05   77.084
# ...             ...
# 2018-03-17  108.124
# 2018-03-18  311.350
# 2018-03-19   44.148
# 2018-03-20   63.260
# 2018-03-21   72.970
#
# [80 rows x 1 columns]
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 79.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqdqummeg/x2aoqz70.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqdqummeg/_c1fl2k2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49701', 'data', 'file=/tmp/tmpqdqummeg/x2aoqz70.json', 'init=/tmp/tmpqdqummeg/_c1fl2k2.json', 'output', 'file=/tmp/tmpqdqummeg/prophet_model4g9s30_7/prophet_model-20230610174034.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:40:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:40:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# ProphetModel(growth = 'linear', changepoints = None, n_changepoints = 100, changepoint_range = 1, yearly_seasonality = 'auto', weekly_seasonality = True, daily_seasonality = 'auto', holidays = None, seasonality_mode = 'additive', seasonality_prior_scale = 10.0, holidays_prior_scale = 10.0, changepoint_prior_scale = 0.05, mcmc_samples = 0, interval_width = 0.8, uncertainty_samples = 1000, stan_backend = None, additional_seasonality_params = (), )

# %%
HORIZON = 79
future_ts = train_ts.make_future(HORIZON)
forecast_ts = model.forecast(future_ts)
# Out:
# /usr/local/lib/python3.10/dist-packages/etna/datasets/tsdataset.py:277: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   future_dates = pd.date_range(

# %%
# from etna.metrics import SMAPE
# smape = SMAPE()
# smape(y_true=test_ts, y_pred=forecast_ts)

# %%
from etna.analysis import plot_forecast

print(forecast_ts)
print(test_ts)
plot_forecast(forecast_ts, test_ts, train_ts, n_train_samples=50)
# Out:
# segment           main
# feature         target
# timestamp
# 2018-03-22  144.502302
# 2018-03-23  207.876983
# 2018-03-24  208.056934
# 2018-03-25  122.155045
# 2018-03-26  171.812464
# ...                ...
# 2018-06-04  118.181317
# 2018-06-05   91.075626
# 2018-06-06    9.125795
# 2018-06-07   85.508041
# 2018-06-08  148.882721
#
# [79 rows x 1 columns]
# segment        main
# feature      target
# timestamp
# 2018-03-22   62.616
# 2018-03-23   43.050
# 2018-03-24   54.208
# 2018-03-25  415.112
# 2018-03-26  312.608
# ...             ...
# 2018-06-04  149.982
# 2018-06-05   56.484
# 2018-06-06  374.428
# 2018-06-07   71.994
# 2018-06-08   52.154
#
# [79 rows x 1 columns]

# %%
from etna.metrics import RMSE
rmse = RMSE()
# test_ts2 = test_ts
# forecast_ts2 = forecast_ts[:20]
rmse(y_true=test_ts, y_pred=forecast_ts)
# Out:
# {'main': 269.1923065648591}

# %%
df = forecast_ts.to_pandas()
print(type(df))
df.columns = ['target']
df['target'] = df['target'].astype(float)
print(df['target'][0])
# df = df.drop(df.index[:2])
# df = df['target'].str.split(' ', expand=True)
# df = df.drop(df.index[:1])
# print(df['timestamp'])
df['target'] = np.exp(df['target'])
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 3.963552509997744
#                target
# timestamp
# 2019-01-02  52.644013
# 2019-01-03  45.352868
# 2019-01-04  46.536799
# 2019-01-05  28.722261
# 2019-01-06  33.044001
# ...               ...
# 2019-07-16  59.837333
# 2019-07-17  49.543838
# 2019-07-18  42.967465
# 2019-07-19  44.018549
# 2019-07-20  26.887168
#
# [200 rows x 1 columns]

# %%
HORIZON = 200
from etna.models import NaiveModel

# Fit the model
model = NaiveModel(lag=20)
model.fit(train_ts)

# Make the forecast
future_ts = train_ts.make_future(future_steps=HORIZON, tail_steps=model.context_size)
forecast_ts = model.forecast(future_ts, prediction_size=HORIZON)

# %%
from etna.metrics import SMAPE

# %%
# smape = SMAPE()
# smape(y_true=test_ts, y_pred=forecast_ts)

# %%
from etna.analysis import plot_forecast

# %%
plot_forecast(forecast_ts, test_ts, train_ts, n_train_samples=100)
