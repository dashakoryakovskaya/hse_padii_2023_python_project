# %%
# !pip install etna
# Out:
# Requirement already satisfied: etna in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (2.0.0)
# Requirement already satisfied: omegaconf<3.0.0,>=2.1.1 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (2.3.0)
# Requirement already satisfied: seaborn<0.12.0,>=0.11.1 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (0.11.2)
# Requirement already satisfied: Deprecated==1.2.13 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (1.2.13)
# Requirement already satisfied: numba<0.56.0,>=0.53.1 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (0.55.2)
# Requirement already satisfied: joblib in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (1.1.0)
# Requirement already satisfied: botocore in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (1.29.142)
# Requirement already satisfied: hydra_slayer in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (0.2.0)
# Requirement already satisfied: typing_extensions in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (4.6.2)
# Requirement already satisfied: boto3<2.0,>=1.5 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (1.26.142)
# Requirement already satisfied: loguru<0.6.0,>=0.5.3 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (0.5.3)
# Requirement already satisfied: typer<0.5.0,>=0.4.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (0.4.2)
# Requirement already satisfied: ruptures==1.1.5 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (1.1.5)
# Requirement already satisfied: tbats<2.0.0,>=1.1.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (1.1.3)
# Requirement already satisfied: pandas<2.0,>=1.1 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (1.5.3)
# Requirement already satisfied: scikit-learn<2,>=0.24 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (1.0.2)
# Requirement already satisfied: dill<0.4.0,>=0.3.4 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (0.3.6)
# Requirement already satisfied: scipy<1.8.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (1.7.3)
# Requirement already satisfied: Bottleneck<2.0.0,>=1.3.4 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (1.3.5)
# Requirement already satisfied: holidays<0.14,>=0.13 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (0.13)
# Requirement already satisfied: pmdarima>=1.8.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (2.0.3)
# Requirement already satisfied: statsmodels<0.14,>=0.12 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (0.13.5)
# Requirement already satisfied: ipywidgets<8.0.0,>=7.6.5 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (7.7.5)
# Requirement already satisfied: toml<0.11.0,>=0.10.2 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (0.10.2)
# Requirement already satisfied: catboost>=0.21 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (1.2)
# Requirement already satisfied: types-Deprecated==1.2.9 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (1.2.9)
# Requirement already satisfied: matplotlib in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (3.5.3)
# Requirement already satisfied: numpy in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (1.22.4)
# Requirement already satisfied: plotly in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from etna) (5.9.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from Deprecated==1.2.13->etna) (1.15.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from boto3<2.0,>=1.5->etna) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from boto3<2.0,>=1.5->etna) (0.6.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from botocore->etna) (1.26.16)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from botocore->etna) (2.8.2)
# Requirement already satisfied: six in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from catboost>=0.21->etna) (1.16.0)
# Requirement already satisfied: graphviz in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from catboost>=0.21->etna) (0.20.1)
# Requirement already satisfied: convertdate>=2.3.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from holidays<0.14,>=0.13->etna) (2.4.0)
# Requirement already satisfied: hijri-converter in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from holidays<0.14,>=0.13->etna) (2.3.1)
# Requirement already satisfied: korean-lunar-calendar in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from holidays<0.14,>=0.13->etna) (0.3.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.6.5->etna) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.6.5->etna) (6.23.1)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.6.5->etna) (1.1.4)
# Requirement already satisfied: widgetsnbextension~=3.6.4 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.6.5->etna) (3.6.4)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.6.5->etna) (5.9.0)
# Requirement already satisfied: ipython>=4.0.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.6.5->etna) (8.13.2)
# Requirement already satisfied: setuptools in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from numba<0.56.0,>=0.53.1->etna) (65.6.3)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from numba<0.56.0,>=0.53.1->etna) (0.38.1)
# Requirement already satisfied: PyYAML>=5.1.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from omegaconf<3.0.0,>=2.1.1->etna) (6.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from omegaconf<3.0.0,>=2.1.1->etna) (4.9.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from pandas<2.0,>=1.1->etna) (2022.7)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from pmdarima>=1.8.0->etna) (0.29.35)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from scikit-learn<2,>=0.24->etna) (2.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from matplotlib->etna) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from matplotlib->etna) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from matplotlib->etna) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from matplotlib->etna) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from matplotlib->etna) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from matplotlib->etna) (23.0)
# Requirement already satisfied: patsy>=0.5.2 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from statsmodels<0.14,>=0.12->etna) (0.5.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from typer<0.5.0,>=0.4.0->etna) (8.1.3)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from plotly->etna) (8.2.2)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from convertdate>=2.3.0->holidays<0.14,>=0.13->etna) (0.5.12)
# Requirement already satisfied: psutil in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.6.5->etna) (5.9.5)
# Requirement already satisfied: nest-asyncio in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.6.5->etna) (1.5.6)
# Requirement already satisfied: appnope in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.6.5->etna) (0.1.3)
# Requirement already satisfied: tornado>=6.1 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.6.5->etna) (6.3)
# Requirement already satisfied: pyzmq>=20 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.6.5->etna) (25.1.0)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.6.5->etna) (1.6.7)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.6.5->etna) (0.1.6)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.6.5->etna) (5.3.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.6.5->etna) (8.2.0)
# Requirement already satisfied: comm>=0.1.1 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.6.5->etna) (0.1.3)
# Requirement already satisfied: decorator in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (5.1.1)
# Requirement already satisfied: pickleshare in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.18.2)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (3.0.38)
# Requirement already satisfied: stack-data in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.6.2)
# Requirement already satisfied: backcall in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (4.8.0)
# Requirement already satisfied: pygments>=2.4.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (2.15.1)
# Requirement already satisfied: notebook>=4.4.1 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (6.5.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.6.5->etna) (3.5.1)
# Requirement already satisfied: jinja2 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (3.1.2)
# Requirement already satisfied: argon2-cffi in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (21.3.0)
# Requirement already satisfied: prometheus-client in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (0.17.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (1.0.0)
# Requirement already satisfied: nbformat in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (5.8.0)
# Requirement already satisfied: nbconvert>=5 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (7.4.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (0.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (1.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.2.5)
# Requirement already satisfied: pure-eval in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.5->etna) (2.2.1)
# Requirement already satisfied: notebook-shim>=0.2.3 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (0.2.3)
# Requirement already satisfied: jupyter-server>=1.8 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (2.6.0)
# Requirement already satisfied: tinycss2 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (1.2.1)
# Requirement already satisfied: defusedxml in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (0.7.1)
# Requirement already satisfied: bleach in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (6.0.0)
# Requirement already satisfied: beautifulsoup4 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (4.12.2)
# Requirement already satisfied: markupsafe>=2.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (2.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (0.8.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (0.2.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (2.0.5)
# Requirement already satisfied: fastjsonschema in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (2.17.1)
# Requirement already satisfied: jsonschema>=2.6 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (4.17.3)
# Requirement already satisfied: argon2-cffi-bindings in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (21.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (0.19.3)
# Requirement already satisfied: overrides in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (7.3.1)
# Requirement already satisfied: jupyter-events>=0.6.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (0.4.4)
# Requirement already satisfied: anyio>=3.1.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (3.7.0)
# Requirement already satisfied: websocket-client in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (1.5.2)
# Requirement already satisfied: cffi>=1.0.1 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (2.4.1)
# Requirement already satisfied: webencodings in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (1.3.0)
# Requirement already satisfied: exceptiongroup in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (1.1.1)
# Requirement already satisfied: idna>=2.8 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (3.4)
# Requirement already satisfied: pycparser in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (2.21)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (0.1.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (0.1.4)
# Requirement already satisfied: fqdn in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (1.5.1)
# Requirement already satisfied: uri-template in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (1.2.0)
# Requirement already satisfied: isoduration in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (2.3)
# Requirement already satisfied: webcolors>=1.11 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages (from isoduration->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0,>=7.6.5->etna) (1.2.3)

# %%
import numpy as np
import pandas as pd
from etna.datasets import TSDataset

# %%
df_flat = pd.read_csv("personal_transactions.csv")
filtered_data = df_flat[df_flat.iloc[:, 3] == "debit"]

# Удаление столбцов
columns_to_drop = [1, 3, 4, 5]
filtered_data = filtered_data.drop(filtered_data.columns[columns_to_drop], axis=1)

# Назначение имен столбцам
filtered_data.columns = ['timestamp', 'target']
filtered_data['timestamp'] = pd.to_datetime(filtered_data['timestamp'])

# Группировка данных по уникальным датам и суммирование чисел
grouped_data = filtered_data.groupby('timestamp')['target'].sum().reset_index()

# Результат
print(grouped_data)
# Out:
#      timestamp   target
# 0   2018-01-01    11.11
# 1   2018-01-02  1271.66
# 2   2018-01-04    11.76
# 3   2018-01-05    25.85
# 4   2018-01-06    18.45
# ..         ...      ...
# 404 2019-09-19    43.56
# 405 2019-09-22   131.10
# 406 2019-09-23    61.77
# 407 2019-09-28    37.73
# 408 2019-09-30    76.75
#
# [409 rows x 2 columns]

# %%
print(grouped_data)
grouped_data = grouped_data.set_index('timestamp')
df_resampled = grouped_data.resample('D').fillna(method='ffill')
df_resampled = df_resampled.reset_index()
# Out:
#      timestamp   target
# 0   2018-01-01    11.11
# 1   2018-01-02  1271.66
# 2   2018-01-04    11.76
# 3   2018-01-05    25.85
# 4   2018-01-06    18.45
# ..         ...      ...
# 404 2019-09-19    43.56
# 405 2019-09-22   131.10
# 406 2019-09-23    61.77
# 407 2019-09-28    37.73
# 408 2019-09-30    76.75
#
# [409 rows x 2 columns]

# %%
df_resampled["segment"] = "main"
# df_resampled['target'] = np.log(df_resampled['target'])
print(df_resampled)
# Out:
#      timestamp   target segment
# 0   2018-01-01    11.11    main
# 1   2018-01-02  1271.66    main
# 2   2018-01-03  1271.66    main
# 3   2018-01-04    11.76    main
# 4   2018-01-05    25.85    main
# ..         ...      ...     ...
# 633 2019-09-26    61.77    main
# 634 2019-09-27    61.77    main
# 635 2019-09-28    37.73    main
# 636 2019-09-29    37.73    main
# 637 2019-09-30    76.75    main
#
# [638 rows x 3 columns]

# %%
# приводим данные к ETNA-формату
df = TSDataset.to_dataset(df_resampled)
ts = TSDataset(df=df, freq = 'D')
print(ts)
# Out:
# segment        main
# feature      target
# timestamp
# 2018-01-01    11.11
# 2018-01-02  1271.66
# 2018-01-03  1271.66
# 2018-01-04    11.76
# 2018-01-05    25.85
# ...             ...
# 2019-09-26    61.77
# 2019-09-27    61.77
# 2019-09-28    37.73
# 2019-09-29    37.73
# 2019-09-30    76.75
#
# [638 rows x 1 columns]

# %%
ts.plot()

# %%
df = ts.to_pandas()
df = df.reset_index()
df.columns = ['timestamp', 'target']

dates = df['timestamp']



wnd_size = 5
df['target'] = df['target'].rolling(window=wnd_size).mean()
df = df[~np.isnan(df).any(axis=1)]
# df['target'] = np.log(df['target'])
# n_magnitude = 500
# df['target'] += np.sin(df.index / 10) * n_magnitude + n_magnitude

# Срез
n_each = 4
df = df.iloc[::n_each]
print(df.shape)

# Возвращение изначальных дат
date_true=df['timestamp']
df.index = range(df.shape[0])
df['timestamp'] = dates[:df.shape[0]]
df_tmp = df.copy()

print(df)

# приводим данные к ETNA-формату
df["segment"] = "main"
df = TSDataset.to_dataset(df)
ts2 = TSDataset(df=df, freq = 'D')
ts2.plot()


tmp = int(df_tmp.shape[0]/2)
train_ts, test_ts = ts2.train_test_split(
    train_start=df_tmp['timestamp'][0],
    train_end=df_tmp['timestamp'][tmp],
    test_start=df_tmp['timestamp'][tmp+1],
    test_end=df_tmp['timestamp'][df_tmp.shape[0]-1],
)
# Out:
# (159, 2)
#      timestamp   target
# 0   2018-01-01  518.408
# 1   2018-01-02   26.764
# 2   2018-01-03   65.786
# 3   2018-01-04   88.444
# 4   2018-01-05   77.084
# ..         ...      ...
# 154 2018-06-04  149.982
# 155 2018-06-05   56.484
# 156 2018-06-06  374.428
# 157 2018-06-07   71.994
# 158 2018-06-08   52.154
#
# [159 rows x 2 columns]

# %%
from etna.models import SARIMAXModel
from etna.analysis import plot_forecast

# Choose a horizon
HORIZON = 79

# Fit the model
model = SARIMAXModel(order = (10,0,0))
# model = ProphetModel()

model.fit(train_ts)

# Make the forecast
future_ts = train_ts.make_future(HORIZON)
forecast_ts = model.forecast(future_ts)

print(train_ts)
print(forecast_ts)

plot_forecast(forecast_ts, test_ts, train_ts,  n_train_samples=200)

plot_forecast(forecast_ts, train_ts,  n_train_samples=200)
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           13     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.21680D+00    |proj g|=  7.31396D-02
#
# At iterate    5    f=  6.20367D+00    |proj g|=  6.93127D-04
#
# At iterate   10    f=  6.20356D+00    |proj g|=  4.33324D-03
#
# At iterate   15    f=  6.19269D+00    |proj g|=  4.30695D-02
#
# At iterate   20    f=  6.17192D+00    |proj g|=  2.13837D-02
#
# At iterate   25    f=  6.17032D+00    |proj g|=  2.27412D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    13     27     31      1     0     0   4.592D-05   6.170D+00
#   F =   6.1703208970773593
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages/etna/models/utils.py:118: FutureWarning: warn is deprecated (and never implemented) and will be removed in a future version.
#   freq = pd.infer_freq(timestamps, warn=False)
# /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages/etna/datasets/tsdataset.py:277: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   future_dates = pd.date_range(
# segment        main
# feature      target
# timestamp
# 2018-01-01  518.408
# 2018-01-02   26.764
# 2018-01-03   65.786
# 2018-01-04   88.444
# 2018-01-05   77.084
# ...             ...
# 2018-03-17  108.124
# 2018-03-18  311.350
# 2018-03-19   44.148
# 2018-03-20   63.260
# 2018-03-21   72.970
#
# [80 rows x 1 columns]
# segment           main
# feature         target
# timestamp
# 2018-03-22  284.756333
# 2018-03-23  -36.412204
# 2018-03-24  109.434139
# 2018-03-25   60.115212
# 2018-03-26   59.103717
# ...                ...
# 2018-06-04   62.858016
# 2018-06-05   26.196285
# 2018-06-06   43.655980
# 2018-06-07  471.192113
# 2018-06-08  180.995817
#
# [79 rows x 1 columns]

# %%
from etna.metrics import RMSE

# %%
rmse = RMSE()
rmse(y_true=test_ts, y_pred=forecast_ts)
# Out:
# {'main': 271.17539261711966}

# %%
from etna.models import ProphetModel

# %%
import holidays

all_holidays = []

for date in holidays.USA(years=[2018, 2019]).items():
  all_holidays.append(str(date[0]))
print(all_holidays)

holidays = pd.DataFrame({
  'holiday': 'playoff',
  'ds': pd.to_datetime(all_holidays),
  'lower_window': 0,
  'upper_window': 1,
})

# вместо holidays - не None

# %%
model = ProphetModel(growth = 'linear', changepoints = None, n_changepoints = 100, changepoint_range = 1, yearly_seasonality = 'auto', weekly_seasonality = True, daily_seasonality = 'auto', holidays = None, seasonality_mode = 'additive', seasonality_prior_scale = 10.0, holidays_prior_scale = 10.0, changepoint_prior_scale = 0.05, mcmc_samples = 0, interval_width = 0.8, uncertainty_samples = 1000, stan_backend = None)
model.fit(train_ts)
# Out:
# 21:09:40 - cmdstanpy - INFO - Chain [1] start processing
# 21:09:40 - cmdstanpy - INFO - Chain [1] done processing
# ProphetModel(growth = 'linear', changepoints = None, n_changepoints = 100, changepoint_range = 1, yearly_seasonality = 'auto', weekly_seasonality = True, daily_seasonality = 'auto', holidays = None, seasonality_mode = 'additive', seasonality_prior_scale = 10.0, holidays_prior_scale = 10.0, changepoint_prior_scale = 0.05, mcmc_samples = 0, interval_width = 0.8, uncertainty_samples = 1000, stan_backend = None, additional_seasonality_params = (), )

# %%
HORIZON = 79
future_ts = train_ts.make_future(HORIZON)
forecast_ts = model.forecast(future_ts)
# Out:
# /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages/etna/datasets/tsdataset.py:277: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   future_dates = pd.date_range(

# %%
# без использования сжатия

from etna.analysis import plot_forecast

test_df = test_ts.to_pandas()
test_df = test_df.reset_index()
test_df = test_df[:79]
test_df.columns = ['timestamp', 'target']
test_df["segment"] = "main"
test_df = TSDataset.to_dataset(test_df)
test_ts2 = TSDataset(df=test_df, freq = 'D')

plot_forecast(forecast_ts, test_ts2, train_ts, n_train_samples=50)

# вместо test_ts использовать test_ts2

# %%
from etna.analysis import plot_forecast

print(forecast_ts)
print(test_ts)
plot_forecast(forecast_ts, test_ts, train_ts, n_train_samples=50)
# Out:
# segment           main
# feature         target
# timestamp
# 2018-03-22  144.502302
# 2018-03-23  207.876983
# 2018-03-24  208.056934
# 2018-03-25  122.155045
# 2018-03-26  171.812464
# ...                ...
# 2018-06-04  118.181317
# 2018-06-05   91.075626
# 2018-06-06    9.125795
# 2018-06-07   85.508041
# 2018-06-08  148.882721
#
# [79 rows x 1 columns]
# segment        main
# feature      target
# timestamp
# 2018-03-22   62.616
# 2018-03-23   43.050
# 2018-03-24   54.208
# 2018-03-25  415.112
# 2018-03-26  312.608
# ...             ...
# 2018-06-04  149.982
# 2018-06-05   56.484
# 2018-06-06  374.428
# 2018-06-07   71.994
# 2018-06-08   52.154
#
# [79 rows x 1 columns]

# %%
from etna.metrics import RMSE
rmse = RMSE()
# test_ts2 = test_ts
# forecast_ts2 = forecast_ts[:20]
rmse(y_true=test_ts, y_pred=forecast_ts)
# Out:
# {'main': 269.19230656483273}

# %%
df = forecast_ts.to_pandas()
df.columns = ['target']
df['target'] = df['target'].astype(float)
df['target'] = np.exp(df['target'])
print(df)
# Out:
#                   target
# timestamp
# 2018-03-22  5.708900e+62
# 2018-03-23  1.904699e+90
# 2018-03-24  2.280228e+90
# 2018-03-25  1.125283e+53
# 2018-03-26  4.141951e+74
# ...                  ...
# 2018-06-04  2.115894e+51
# 2018-06-05  3.578013e+39
# 2018-06-06  9.189300e+03
# 2018-06-07  1.366691e+37
# 2018-06-08  4.559785e+64
#
# [79 rows x 1 columns]

# %%
HORIZON = 200
from etna.models import NaiveModel

# Fit the model
model = NaiveModel(lag=20)
model.fit(train_ts)

# Make the forecast
future_ts = train_ts.make_future(future_steps=HORIZON, tail_steps=model.context_size)
forecast_ts = model.forecast(future_ts, prediction_size=HORIZON)
# Out:
# /Users/nad/opt/anaconda3/envs/tg_bot3/lib/python3.10/site-packages/etna/datasets/tsdataset.py:277: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   future_dates = pd.date_range(

# %%
from etna.analysis import plot_forecast

# %%
plot_forecast(forecast_ts, test_ts, train_ts, n_train_samples=100)
